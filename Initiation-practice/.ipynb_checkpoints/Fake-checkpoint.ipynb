# %%
import pandas as pd
import os
# Read data into papers
papers = pd.read_csv('/home/purvj/Documents/Final Year Project/CSV/womens.csv')
# Print head
papers.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0         NaN          767   33                      NaN
# 1         NaN         1080   34                      NaN
# 2         NaN         1077   60  Some major design flaws
# 3         NaN         1049   50         My favorite buy!
# 4         NaN          847   47         Flattering shirt
#
#                                          Review-Text Rating Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...      4               1
# 1  Love this dress!  it's sooo pretty.  i happene...      5               1
# 2  I had such high hopes for this dress and reall...      3               0
# 3  I love, love, love this jumpsuit. it's fun, fl...      5               1
# 4  This shirt is very flattering to all due to th...      5               1
#
#   Positive Feedback Count   Division Name Department Name Class Name  \
# 0                       0       Initmates        Intimate  Intimates
# ...

# %%
papers = papers.drop(columns=['Clothing ID', 'Age','Title','Rating','Recommended IND','Positive Feedback Count','Division Name','Department Name','Class Name'], axis=1).sample(100)
papers.head()
# Out:
#        Unnamed: 0                                        Review-Text  \
# 4270          NaN  I may wear these every day! i am obsessed. i a...
# 3660          NaN  I'm normally a size 25p. i bought these in a 2...
# 20667         NaN  Although it was a bit of a battle with my bra ...
# 20166         NaN                                                NaN
# 1596          NaN  Love these pants. the design is totally differ...
#
#       Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 4270          NaN         NaN         NaN         NaN         NaN         NaN
# 3660          NaN         NaN         NaN         NaN         NaN         NaN
# 20667         NaN         NaN         NaN         NaN         NaN         NaN
# 20166         NaN         NaN         NaN         NaN         NaN         NaN
# 1596          NaN         NaN         NaN         NaN         NaN         NaN
#
#       Unnamed: 17 Unnamed: 18
# 4270          NaN         NaN
# ...

# %%
import re
papers['ReviewText_processed'] = \
papers['ReviewText'].map(lambda x: re.sub('[,\.!?]', '', x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5d99f55f434d> in <module>
#       1 import re
#       2 papers['Review-Text_processed'] = \
# ----> 3 papers['Review-Text'].map(lambda x: re.sub('[,\.!?]', '', x))
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# ~/.local/lib/python3.8/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
# ...
